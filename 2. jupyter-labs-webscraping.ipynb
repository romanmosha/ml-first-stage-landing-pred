# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2023.5.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/91.0.4472.124 Safari/537.36"
}

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url and headers
response = requests.get(static_url, headers=headers)
response.status_code
# Out:
# 200

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text,'html')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
soup.title.string
# Out:
# 'List of Falcon 9 and Falcon Heavy launches - Wikipedia'

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')
print(f"No. of tables found: {len(html_tables)}")
# Out:
# No. of tables found: 25

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable plainrowheaders collapsible" style="width: 100%;">
# <tbody><tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11"><span class="cite-bracket">[</span>b<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">1
# </th>
# <td>4 June 2010,<br/>18:45
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-0"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B0003.1<sup class="reference" id="cite_ref-block_numbers_14-0"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Dragon_Spacecraft_Qualification_Unit" title="Dragon Spacecraft Qualification Unit">Dragon Spacecraft Qualification Unit</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-failure" style="background: #FFC7C7; color:black; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-0"><a href="#cite_note-ns20110930-15"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16"><span class="cite-bracket">[</span>10<span class="cite-bracket">]</span></a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">First flight of Falcon 9 v1.0.<sup class="reference" id="cite_ref-sfn20100604_17-0"><a href="#cite_note-sfn20100604-17"><span class="cite-bracket">[</span>11<span class="cite-bracket">]</span></a></sup> Used a boilerplate version of Dragon capsule which was not designed to separate from the second stage.<small>(<a href="#First_flight_of_Falcon_9">more details below</a>)</small> Attempted to recover the first stage by parachuting it into the ocean, but it burned up on reentry, before the parachutes even deployed.<sup class="reference" id="cite_ref-parachute_18-0"><a href="#cite_note-parachute-18"><span class="cite-bracket">[</span>12<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">2
# </th>
# <td>8 December 2010,<br/>15:43<sup class="reference" id="cite_ref-spaceflightnow_Clark_Launch_Report_19-0"><a href="#cite_note-spaceflightnow_Clark_Launch_Report-19"><span class="cite-bracket">[</span>13<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-1"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B0004.1<sup class="reference" id="cite_ref-block_numbers_14-1"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/COTS_Demo_Flight_1" title="COTS Demo Flight 1">demo flight C1</a><br/>(Dragon C101)
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-ns20110930_15-1"><a href="#cite_note-ns20110930-15"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a></sup>
# </td>
# <td class="table-failure" style="background: #FFC7C7; color:black; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-2"><a href="#cite_note-ns20110930-15"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20"><span class="cite-bracket">[</span>14<span class="cite-bracket">]</span></a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">Maiden flight of <a class="mw-redirect" href="/wiki/Dragon_capsule" title="Dragon capsule">Dragon capsule</a>, consisting of over 3 hours of testing thruster maneuvering and reentry.<sup class="reference" id="cite_ref-spaceflightnow_Clark_unleashing_Dragon_21-0"><a href="#cite_note-spaceflightnow_Clark_unleashing_Dragon-21"><span class="cite-bracket">[</span>15<span class="cite-bracket">]</span></a></sup> Attempted to recover the first stage by parachuting it into the ocean, but it disintegrated upon reentry, before the parachutes were deployed.<sup class="reference" id="cite_ref-parachute_18-1"><a href="#cite_note-parachute-18"><span class="cite-bracket">[</span>12<span class="cite-bracket">]</span></a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small> It also included two <a href="/wiki/CubeSat" title="CubeSat">CubeSats</a>,<sup class="reference" id="cite_ref-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats_22-0"><a href="#cite_note-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats-22"><span class="cite-bracket">[</span>16<span class="cite-bracket">]</span></a></sup> and a wheel of <a href="/wiki/Brou%C3%A8re" title="Brouère">Brouère</a> cheese.
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">3
# </th>
# <td>22 May 2012,<br/>07:44<sup class="reference" id="cite_ref-BBC_new_era_23-0"><a href="#cite_note-BBC_new_era-23"><span class="cite-bracket">[</span>17<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-2"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B0005.1<sup class="reference" id="cite_ref-block_numbers_14-2"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/Dragon_C2%2B" title="Dragon C2+">demo flight C2+</a><sup class="reference" id="cite_ref-C2_24-0"><a href="#cite_note-C2-24"><span class="cite-bracket">[</span>18<span class="cite-bracket">]</span></a></sup><br/>(Dragon C102)
# </td>
# <td>525 kg (1,157 lb)<sup class="reference" id="cite_ref-25"><a href="#cite_note-25"><span class="cite-bracket">[</span>19<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-26"><a href="#cite_note-26"><span class="cite-bracket">[</span>20<span class="cite-bracket">]</span></a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; color:black; vertical-align: middle; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Dragon spacecraft demonstrated a series of tests before it was allowed to approach the <a href="/wiki/International_Space_Station" title="International Space Station">International Space Station</a>. Two days later, it became the first commercial spacecraft to board the ISS.<sup class="reference" id="cite_ref-BBC_new_era_23-1"><a href="#cite_note-BBC_new_era-23"><span class="cite-bracket">[</span>17<span class="cite-bracket">]</span></a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="3" scope="row" style="text-align:center;">4
# </th>
# <td rowspan="2">8 October 2012,<br/>00:35<sup class="reference" id="cite_ref-SFN_LLog_27-0"><a href="#cite_note-SFN_LLog-27"><span class="cite-bracket">[</span>21<span class="cite-bracket">]</span></a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-3"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B0006.1<sup class="reference" id="cite_ref-block_numbers_14-3"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-1" title="SpaceX CRS-1">SpaceX CRS-1</a><sup class="reference" id="cite_ref-sxManifest20120925_28-0"><a href="#cite_note-sxManifest20120925-28"><span class="cite-bracket">[</span>22<span class="cite-bracket">]</span></a></sup><br/>(Dragon C103)
# </td>
# <td>4,700 kg (10,400 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success
# </td>
# <td rowspan="2" style="background:#ececec; text-align:center;"><span class="nowrap">No attempt</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Orbcomm_(satellite)" title="Orbcomm (satellite)">Orbcomm-OG2</a><sup class="reference" id="cite_ref-Orbcomm_29-0"><a href="#cite_note-Orbcomm-29"><span class="cite-bracket">[</span>23<span class="cite-bracket">]</span></a></sup>
# </td>
# <td>172 kg (379 lb)<sup class="reference" id="cite_ref-gunter-og2_30-0"><a href="#cite_note-gunter-og2-30"><span class="cite-bracket">[</span>24<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# <td class="table-partial" style="background: #FFB; color:black; vertical-align: middle; text-align: center;">Partial failure<sup class="reference" id="cite_ref-nyt-20121030_31-0"><a href="#cite_note-nyt-20121030-31"><span class="cite-bracket">[</span>25<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <td colspan="9">CRS-1 was successful, but the <a href="/wiki/Secondary_payload" title="Secondary payload">secondary payload</a> was inserted into an abnormally low orbit and subsequently lost. This was due to one of the nine <a href="/wiki/SpaceX_Merlin" title="SpaceX Merlin">Merlin engines</a> shutting down during the launch, and NASA declining a second reignition, as per <a href="/wiki/International_Space_Station" title="International Space Station">ISS</a> visiting vehicle safety rules, the primary payload owner is contractually allowed to decline a second reignition. NASA stated that this was because SpaceX could not guarantee a high enough likelihood of the second stage completing the second burn successfully which was required to avoid any risk of secondary payload's collision with the ISS.<sup class="reference" id="cite_ref-OrbcommTotalLoss_32-0"><a href="#cite_note-OrbcommTotalLoss-32"><span class="cite-bracket">[</span>26<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-sn20121011_33-0"><a href="#cite_note-sn20121011-33"><span class="cite-bracket">[</span>27<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34"><span class="cite-bracket">[</span>28<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">5
# </th>
# <td>1 March 2013,<br/>15:10
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-4"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B0007.1<sup class="reference" id="cite_ref-block_numbers_14-4"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-2" title="SpaceX CRS-2">SpaceX CRS-2</a><sup class="reference" id="cite_ref-sxManifest20120925_28-1"><a href="#cite_note-sxManifest20120925-28"><span class="cite-bracket">[</span>22<span class="cite-bracket">]</span></a></sup><br/>(Dragon C104)
# </td>
# <td>4,877 kg (10,752 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-noAttempt" style="background: #EEE; color:black; vertical-align: middle; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Last launch of the original Falcon 9 v1.0 <a href="/wiki/Launch_vehicle" title="Launch vehicle">launch vehicle</a>, first use of the unpressurized trunk section of Dragon.<sup class="reference" id="cite_ref-sxf9_20110321_35-0"><a href="#cite_note-sxf9_20110321-35"><span class="cite-bracket">[</span>29<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">6
# </th>
# <td>29 September 2013,<br/>16:00<sup class="reference" id="cite_ref-pa20130930_36-0"><a href="#cite_note-pa20130930-36"><span class="cite-bracket">[</span>30<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><sup class="reference" id="cite_ref-MuskMay2012_13-5"><a href="#cite_note-MuskMay2012-13"><span class="cite-bracket">[</span>7<span class="cite-bracket">]</span></a></sup><br/>B1003<sup class="reference" id="cite_ref-block_numbers_14-5"><a href="#cite_note-block_numbers-14"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Vandenberg_Air_Force_Base" title="Vandenberg Air Force Base">VAFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/CASSIOPE" title="CASSIOPE">CASSIOPE</a><sup class="reference" id="cite_ref-sxManifest20120925_28-2"><a href="#cite_note-sxManifest20120925-28"><span class="cite-bracket">[</span>22<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-CASSIOPE_MDA_37-0"><a href="#cite_note-CASSIOPE_MDA-37"><span class="cite-bracket">[</span>31<span class="cite-bracket">]</span></a></sup>
# </td>
# <td>500 kg (1,100 lb)
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar orbit</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-pa20130930_36-1"><a href="#cite_note-pa20130930-36"><span class="cite-bracket">[</span>30<span class="cite-bracket">]</span></a></sup>
# </td>
# <td class="table-no2" style="background: #FFE3E3; color: black; vertical-align: middle; text-align: center;">Uncontrolled<br/><small>(ocean)</small><sup class="reference" id="cite_ref-ocean_landing_38-0"><a href="#cite_note-ocean_landing-38"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First commercial mission with a private customer, first launch from Vandenberg, and demonstration flight of Falcon 9 v1.1 with an improved 13-tonne to LEO capacity.<sup class="reference" id="cite_ref-sxf9_20110321_35-1"><a href="#cite_note-sxf9_20110321-35"><span class="cite-bracket">[</span>29<span class="cite-bracket">]</span></a></sup> After separation from the second stage carrying Canadian commercial and scientific satellites, the first stage booster performed a controlled reentry,<sup class="reference" id="cite_ref-39"><a href="#cite_note-39"><span class="cite-bracket">[</span>32<span class="cite-bracket">]</span></a></sup> and an <a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">ocean touchdown test</a> for the first time. This provided good test data, even though the booster started rolling as it neared the ocean, leading to the shutdown of the central engine as the roll depleted it of fuel, resulting in a hard impact with the ocean.<sup class="reference" id="cite_ref-pa20130930_36-2"><a href="#cite_note-pa20130930-36"><span class="cite-bracket">[</span>30<span class="cite-bracket">]</span></a></sup> This was the first known attempt of a rocket engine being lit to perform a supersonic retro propulsion, and allowed SpaceX to enter a public-private partnership with <a href="/wiki/NASA" title="NASA">NASA</a> and its Mars entry, descent, and landing technologies research projects.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40"><span class="cite-bracket">[</span>33<span class="cite-bracket">]</span></a></sup> <small>(<a href="#Maiden_flight_of_v1.1">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">7
# </th>
# <td>3 December 2013,<br/>22:41<sup class="reference" id="cite_ref-sfn_wwls20130624_41-0"><a href="#cite_note-sfn_wwls20130624-41"><span class="cite-bracket">[</span>34<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SES-8" title="SES-8">SES-8</a><sup class="reference" id="cite_ref-sxManifest20120925_28-3"><a href="#cite_note-sxManifest20120925-28"><span class="cite-bracket">[</span>22<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-spx-pr_42-0"><a href="#cite_note-spx-pr-42"><span class="cite-bracket">[</span>35<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-aw20110323_43-0"><a href="#cite_note-aw20110323-43"><span class="cite-bracket">[</span>36<span class="cite-bracket">]</span></a></sup>
# </td>
# <td>3,170 kg (6,990 lb)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-SNMissionStatus7_44-0"><a href="#cite_note-SNMissionStatus7-44"><span class="cite-bracket">[</span>37<span class="cite-bracket">]</span></a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; color:black; vertical-align: middle; text-align: center;">No attempt<br/><sup class="reference" id="cite_ref-sf10120131203_45-0"><a href="#cite_note-sf10120131203-45"><span class="cite-bracket">[</span>38<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Geostationary transfer orbit</a> (GTO) launch for Falcon 9,<sup class="reference" id="cite_ref-spx-pr_42-1"><a href="#cite_note-spx-pr-42"><span class="cite-bracket">[</span>35<span class="cite-bracket">]</span></a></sup> and first successful reignition of the second stage.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46"><span class="cite-bracket">[</span>39<span class="cite-bracket">]</span></a></sup> SES-8 was inserted into a <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Super-Synchronous Transfer Orbit</a> of 79,341 km (49,300 mi) in apogee with an <a href="/wiki/Orbital_inclination" title="Orbital inclination">inclination</a> of 20.55° to the <a href="/wiki/Equator" title="Equator">equator</a>.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
header_cells = first_launch_table.find_all('th')
for th in header_cells:
    name=extract_column_from_header(th)
    if name is not None and len(name)>0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0

for table_number, table in enumerate(soup.find_all('table', "wikitable plainrowheaders collapsible")):
    for rows in table.find_all("tr"):
        if rows.th:
            if rows.th.string:
                flight_number = rows.th.string.strip()
                flag = flight_number.isdigit()
        else:
            flag = False
        
        row = rows.find_all('td')
        
        if flag:
            extracted_row += 1
            # Initialize a new dictionary for this row based on column names
            launch_dict = dict.fromkeys(column_names)
            
            # Flight Number value
            launch_dict['Flight No.'] = flight_number
            
            # Assuming the rest of the columns correspond to the td elements in order
            for i, cell in enumerate(row):
                # Extract text from each cell, strip whitespace
                cell_text = cell.get_text(strip=True)
                
                # Assign cell_text to the corresponding column name if it exists
                if i + 1 < len(column_names):  # +1 because 'Flight No.' is from th, so td starts from index 1
                    launch_dict[column_names[i + 1]] = cell_text
            
            print(launch_dict)  # You can replace this with appending to a list for further processing
# Out:
# {'Flight No.': '1', 'Date and time ( )': '4 June 2010,18:45', 'Launch site': 'F9 v1.0[7]B0003.1[8]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Dragon Spacecraft Qualification Unit', 'Orbit': '', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '2', 'Date and time ( )': '8 December 2010,15:43[13]', 'Launch site': 'F9 v1.0[7]B0004.1[8]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Dragondemo flight C1(Dragon C101)', 'Orbit': '', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(COTS)NRO'}
# {'Flight No.': '3', 'Date and time ( )': '22 May 2012,07:44[17]', 'Launch site': 'F9 v1.0[7]B0005.1[8]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Dragondemo flight C2+[18](Dragon C102)', 'Orbit': '525\xa0kg (1,157\xa0lb)[19]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(COTS)'}
# {'Flight No.': '4', 'Date and time ( )': '8 October 2012,00:35[21]', 'Launch site': 'F9 v1.0[7]B0006.1[8]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-1[22](Dragon C103)', 'Orbit': '4,700\xa0kg (10,400\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '5', 'Date and time ( )': '1 March 2013,15:10', 'Launch site': 'F9 v1.0[7]B0007.1[8]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-2[22](Dragon C104)', 'Orbit': '4,877\xa0kg (10,752\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '6', 'Date and time ( )': '29 September 2013,16:00[30]', 'Launch site': 'F9 v1.1[7]B1003[8]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'CASSIOPE[22][31]', 'Orbit': '500\xa0kg (1,100\xa0lb)', 'Customer': 'Polar orbitLEO', 'Launch outcome': 'MDA'}
# {'Flight No.': '7', 'Date and time ( )': '3 December 2013,22:41[34]', 'Launch site': 'F9 v1.1B1004', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SES-8[22][35][36]', 'Orbit': '3,170\xa0kg (6,990\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'SES'}
# {'Flight No.': '8', 'Date and time ( )': '6 January 2014,22:06[41]', 'Launch site': 'F9 v1.1', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Thaicom 6[22]', 'Orbit': '3,325\xa0kg (7,330\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Thaicom'}
# {'Flight No.': '9', 'Date and time ( )': '18 April 2014,19:25[21]', 'Launch site': 'F9 v1.1', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-3[22](Dragon C105)', 'Orbit': '2,296\xa0kg (5,062\xa0lb)[45]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '10', 'Date and time ( )': '14 July 2014,15:15', 'Launch site': 'F9 v1.1', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'Orbcomm-OG2-1(6 satellites)[22]', 'Orbit': '1,316\xa0kg (2,901\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'Orbcomm'}
# {'Flight No.': '11', 'Date and time ( )': '5 August 2014,08:00', 'Launch site': 'F9 v1.1', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'AsiaSat 8[22][54][55]', 'Orbit': '4,535\xa0kg (9,998\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'AsiaSat'}
# {'Flight No.': '12', 'Date and time ( )': '7 September 2014,05:00', 'Launch site': 'F9 v1.1B1011[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'AsiaSat 6[22][54][58]', 'Orbit': '4,428\xa0kg (9,762\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'AsiaSat'}
# {'Flight No.': '13', 'Date and time ( )': '21 September 2014,05:52[21]', 'Launch site': 'F9 v1.1B1010[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-4[22](DragonC106.1)', 'Orbit': '2,216\xa0kg (4,885\xa0lb)[62]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '14', 'Date and time ( )': '10 January 2015,09:47[67]', 'Launch site': 'F9 v1.1B1012[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-5[68](Dragon C107)', 'Orbit': '2,395\xa0kg (5,280\xa0lb)[69]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '15', 'Date and time ( )': '11 February 2015,23:03[72]', 'Launch site': 'F9 v1.1B1013[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'DSCOVR[68][73]', 'Orbit': '570\xa0kg (1,260\xa0lb)', 'Customer': 'HEO(Sun–Earth L1insertion)', 'Launch outcome': 'USAFNASANOAA'}
# {'Flight No.': '16', 'Date and time ( )': '2 March 2015,03:50[21][76]', 'Launch site': 'F9 v1.1B1014[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'ABS-3AEutelsat 115 West B[68]', 'Orbit': '4,159\xa0kg (9,169\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'ABSEutelsat'}
# {'Flight No.': '17', 'Date and time ( )': '14 April 2015,20:10[21]', 'Launch site': 'F9 v1.1B1015[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-6[68](DragonC108.1)', 'Orbit': '1,898\xa0kg (4,184\xa0lb)[82]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '18', 'Date and time ( )': '27 April 2015,23:03[86]', 'Launch site': 'F9 v1.1B1016[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'TürkmenÄlem 52°E / MonacoSAT[68][87]', 'Orbit': '4,707\xa0kg (10,377\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Turkmenistan NationalSpace Agency[88]'}
# {'Flight No.': '19', 'Date and time ( )': '28 June 2015,14:21[21][91]', 'Launch site': 'F9 v1.1B1018[8]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-7[68](Dragon C109)', 'Orbit': '1,952\xa0kg (4,303\xa0lb)[92]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '20', 'Date and time ( )': '22 December 2015,01:29[97]', 'Launch site': 'F9 FTB1019.1[98]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'Orbcomm-OG2-2(11 satellites)[22][97]', 'Orbit': '2,034\xa0kg (4,484\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'Orbcomm'}
# {'Flight No.': '21', 'Date and time ( )': '17 January 2016,18:42[21]', 'Launch site': 'F9 v1.1B1017[8]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Jason-3[68][104]', 'Orbit': '553\xa0kg (1,219\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'NASA(LSP)NOAACNES'}
# {'Flight No.': '22', 'Date and time ( )': '4 March 2016,23:35[21]', 'Launch site': 'F9 FTB1020.1[108]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SES-9[68][109][110]', 'Orbit': '5,271\xa0kg (11,621\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'SES'}
# {'Flight No.': '23', 'Date and time ( )': '8 April 2016,20:43[21]', 'Launch site': 'F9 FTB1021.1[115]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-8[68][110](Dragon C110.1)', 'Orbit': '3,136\xa0kg (6,914\xa0lb)[116]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '24', 'Date and time ( )': '6 May 2016,05:21[21]', 'Launch site': 'F9 FTB1022.1[122]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'JCSAT-14[123]', 'Orbit': '4,696\xa0kg (10,353\xa0lb)[124]', 'Customer': 'GTO', 'Launch outcome': 'SKY Perfect JSAT Group'}
# {'Flight No.': '25', 'Date and time ( )': '27 May 2016,21:39[128]', 'Launch site': 'F9 FTB1023.1[129]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'Thaicom 8[130][131]', 'Orbit': '3,100\xa0kg (6,800\xa0lb)[132]', 'Customer': 'GTO', 'Launch outcome': 'Thaicom'}
# {'Flight No.': '26', 'Date and time ( )': '15 June 2016,14:29[21]', 'Launch site': 'F9 FTB1024.1[108]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'ABS-2AEutelsat 117 West B[68]', 'Orbit': '3,600\xa0kg (7,900\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'ABSEutelsat'}
# {'Flight No.': '27', 'Date and time ( )': '18 July 2016,04:45[21]', 'Launch site': 'F9 FTB1025.1[129]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'SpaceX CRS-9[68][141](Dragon C111.1)', 'Orbit': '2,257\xa0kg (4,976\xa0lb)[142]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '28', 'Date and time ( )': '14 August 2016,05:26', 'Launch site': 'F9 FTB1026.1[108]', 'Payload': 'Cape Canaveral,LC-40', 'Payload mass': 'JCSAT-16', 'Orbit': '4,600\xa0kg (10,100\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'SKY Perfect JSAT Group'}
# {'Flight No.': '29', 'Date and time ( )': '14 January 2017,17:54', 'Launch site': 'F9 FTB1029.1[151]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-1(10 satellites)[152][153]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '30', 'Date and time ( )': '19 February 2017,14:39', 'Launch site': 'F9 FTB1031.1[8]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SpaceX CRS-10[141](Dragon C112.1)', 'Orbit': '2,490\xa0kg (5,490\xa0lb)[160]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '31', 'Date and time ( )': '16 March 2017,06:00', 'Launch site': 'F9 FTB1030.1[163]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'EchoStar 23', 'Orbit': '5,600\xa0kg (12,300\xa0lb)[164]', 'Customer': 'GTO', 'Launch outcome': 'EchoStar'}
# {'Flight No.': '32', 'Date and time ( )': '30 March 2017,22:27', 'Launch site': 'F9 FT♺B1021.2[115]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SES-10[109][168]', 'Orbit': '5,300\xa0kg (11,700\xa0lb)[169]', 'Customer': 'GTO', 'Launch outcome': 'SES'}
# {'Flight No.': '33', 'Date and time ( )': '1 May 2017,11:15', 'Launch site': 'F9 FTB1032.1[129]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'NROL-76[174]', 'Orbit': 'Classified', 'Customer': 'LEO[175]', 'Launch outcome': 'NRO'}
# {'Flight No.': '34', 'Date and time ( )': '15 May 2017,23:21', 'Launch site': 'F9 FTB1034.1[179]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Inmarsat-5 F4[180]', 'Orbit': '6,070\xa0kg (13,380\xa0lb)[181]', 'Customer': 'GTO', 'Launch outcome': 'Inmarsat'}
# {'Flight No.': '35', 'Date and time ( )': '3 June 2017,21:07', 'Launch site': 'F9 FTB1035.1[185]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SpaceX CRS-11[141](Dragon C106.2 ♺)', 'Orbit': '2,708\xa0kg (5,970\xa0lb)[186]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '36', 'Date and time ( )': '23 June 2017,19:10', 'Launch site': 'F9 FT♺B1029.2[195]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'BulgariaSat-1[196]', 'Orbit': '3,669\xa0kg (8,089\xa0lb)[197]', 'Customer': 'GTO', 'Launch outcome': 'Bulsatcom'}
# {'Flight No.': '37', 'Date and time ( )': '25 June 2017,20:25', 'Launch site': 'F9 FTB1036.1[198]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-2(10 satellites)', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '38', 'Date and time ( )': '5 July 2017,23:38', 'Launch site': 'F9 FTB1037.1[200]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Intelsat 35e[201]', 'Orbit': '6,761\xa0kg (14,905\xa0lb)[202]', 'Customer': 'GTO', 'Launch outcome': 'Intelsat'}
# {'Flight No.': '39', 'Date and time ( )': '14 August 2017,16:31', 'Launch site': 'F9 B4B1039.1[207]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SpaceX CRS-12[141](Dragon C113.1)', 'Orbit': '3,310\xa0kg (7,300\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '40', 'Date and time ( )': '24 August 2017,18:51', 'Launch site': 'F9 FTB1038.1[209]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Formosat-5[210][211]', 'Orbit': '475\xa0kg (1,047\xa0lb)[212]', 'Customer': 'SSO', 'Launch outcome': 'NSPO'}
# {'Flight No.': '41', 'Date and time ( )': '7 September 2017,14:00[215]', 'Launch site': 'F9 B4B1040.1[108]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Boeing X-37BOTV-5', 'Orbit': '4,990\xa0kg (11,000\xa0lb)[216]+ OTV payload', 'Customer': 'LEO', 'Launch outcome': 'USAF'}
# {'Flight No.': '42', 'Date and time ( )': '9 October 2017,12:37', 'Launch site': 'F9 B4B1041.1[219]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-3(10 satellites)[152]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '43', 'Date and time ( )': '11 October 2017,22:53:00', 'Launch site': 'F9 FT♺B1031.2[220]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SES-11/EchoStar 105', 'Orbit': '5,200\xa0kg (11,500\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'SES S.A.EchoStar'}
# {'Flight No.': '44', 'Date and time ( )': '30 October 2017,19:34', 'Launch site': 'F9 B4B1042.1[219]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Koreasat 5A[222]', 'Orbit': '3,500\xa0kg (7,700\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'KT Corporation'}
# {'Flight No.': '45', 'Date and time ( )': '15 December 2017,15:36[226]', 'Launch site': 'F9 FT♺B1035.2[227]', 'Payload': 'Cape Canaveral,SLC-40', 'Payload mass': 'SpaceX CRS-13[141](Dragon C108.2 ♺)', 'Orbit': '2,205\xa0kg (4,861\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '46', 'Date and time ( )': '23 December 2017,01:27[229]', 'Launch site': 'F9 FT♺B1036.2[227]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-4(10 satellites)[152]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '47', 'Date and time ( )': '8 January 2018,01:00[237]', 'Launch site': 'F9 B4B1043.1[238]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Zuma[238][239][240]', 'Orbit': 'Classified', 'Customer': 'LEO', 'Launch outcome': 'Northrop Grumman[f][238]'}
# {'Flight No.': '48', 'Date and time ( )': '31 January 2018,21:25[244]', 'Launch site': 'F9 FT♺B1032.2[245]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'GovSat-1(SES-16)[246]', 'Orbit': '4,230\xa0kg (9,330\xa0lb)[247]', 'Customer': 'GTO', 'Launch outcome': 'SES'}
# {'Flight No.': '49', 'Date and time ( )': '22 February 2018,14:17[267]', 'Launch site': 'F9 FT♺B1038.2[268]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Paz[269]Tintin A and Tintin B[270]', 'Orbit': '2,150\xa0kg (4,740\xa0lb)', 'Customer': 'SSO', 'Launch outcome': 'HisdesatexactEarthSpaceX'}
# {'Flight No.': '50', 'Date and time ( )': '6 March 2018,05:33[276]', 'Launch site': 'F9 B4B1044.1[108]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Hispasat 30W-6[277]PODSat[278]', 'Orbit': '6,092\xa0kg (13,431\xa0lb)[279]', 'Customer': 'GTO', 'Launch outcome': 'Hispasat[277]NovaWurks'}
# {'Flight No.': '51', 'Date and time ( )': '30 March 2018,14:14[285]', 'Launch site': 'F9 B4♺B1041.2[268]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-5(10 satellites)[152]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '52', 'Date and time ( )': '2 April 2018,20:30[291]', 'Launch site': 'F9 B4♺B1039.2[292]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-14[141](Dragon C110.2 ♺)', 'Orbit': '2,647\xa0kg (5,836\xa0lb)[292]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '53', 'Date and time ( )': '18 April 2018,22:51[303]', 'Launch site': 'F9 B4B1045.1[268]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Transiting Exoplanet Survey Satellite(TESS)[304]', 'Orbit': '362\xa0kg (798\xa0lb)[305]', 'Customer': 'HEOforP/2 orbit', 'Launch outcome': 'NASA(LSP)'}
# {'Flight No.': '54', 'Date and time ( )': '11 May 2018,20:14[310]', 'Launch site': 'F9 B5[311]B1046.1[268]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Bangabandhu-1[312][313]', 'Orbit': '3,600\xa0kg (7,900\xa0lb)[314]', 'Customer': 'GTO', 'Launch outcome': 'Thales-Alenia/BTRC'}
# {'Flight No.': '55', 'Date and time ( )': '22 May 2018,19:47[321]', 'Launch site': 'F9 B4♺B1043.2[322]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-6(5 satellites)[152][155]GRACE-FO× 2[323][324]', 'Orbit': '6,460\xa0kg (14,240\xa0lb)[g]', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium CommunicationsGFZ•NASA'}
# {'Flight No.': '56', 'Date and time ( )': '4 June 2018,04:45[330]', 'Launch site': 'F9 B4♺B1040.2[268]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SES-12[331]', 'Orbit': '5,384\xa0kg (11,870\xa0lb)[332]', 'Customer': 'GTO', 'Launch outcome': 'SES'}
# {'Flight No.': '57', 'Date and time ( )': '29 June 2018,09:42[335]', 'Launch site': 'F9 B4♺B1045.2[336]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-15(Dragon C111.2 ♺)', 'Orbit': '2,697\xa0kg (5,946\xa0lb)[337]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '58', 'Date and time ( )': '22 July 2018,05:50[340]', 'Launch site': 'F9 B5B1047.1', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Telstar 19V[341]', 'Orbit': '7,075\xa0kg (15,598\xa0lb)[342]', 'Customer': 'GTO[343]', 'Launch outcome': 'Telesat'}
# {'Flight No.': '59', 'Date and time ( )': '25 July 2018,11:39[348]', 'Launch site': 'F9 B5[349]B1048.1[350]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-7(10 satellites)[152]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '60', 'Date and time ( )': '7 August 2018,05:18[353]', 'Launch site': 'F9 B5♺B1046.2[354]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Merah Putih(formerly Telkom 4)[355][356]', 'Orbit': '5,800\xa0kg (12,800\xa0lb)[357]', 'Customer': 'GTO', 'Launch outcome': 'Telkom Indonesia'}
# {'Flight No.': '61', 'Date and time ( )': '10 September 2018,04:45[361]', 'Launch site': 'F9 B5B1049.1[268]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Telstar 18V/Apstar-5C[341]', 'Orbit': '7,060\xa0kg (15,560\xa0lb)[361]', 'Customer': 'GTO[361]', 'Launch outcome': 'Telesat'}
# {'Flight No.': '62', 'Date and time ( )': '8 October 2018,02:22[363]', 'Launch site': 'F9 B5♺B1048.2[364]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'SAOCOM 1A[365][366]', 'Orbit': '3,000\xa0kg (6,600\xa0lb)[363]', 'Customer': 'SSO', 'Launch outcome': 'CONAE'}
# {'Flight No.': '63', 'Date and time ( )': '15 November 2018,20:46[367]', 'Launch site': 'F9 B5♺B1047.2[268]', 'Payload': 'KSC,LC-39A', 'Payload mass': "Es'hail 2[368]", 'Orbit': '5,300\xa0kg (11,700\xa0lb)[369]', 'Customer': 'GTO', 'Launch outcome': "Es'hailSat"}
# {'Flight No.': '64', 'Date and time ( )': '3 December 2018,18:34:05', 'Launch site': 'F9 B5♺B1046.3[268]SHERPA', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'SSO-A(SmallSat Express)', 'Orbit': '~4,000\xa0kg (8,800\xa0lb)[372]', 'Customer': 'SSO', 'Launch outcome': 'Spaceflight Industries'}
# {'Flight No.': '65', 'Date and time ( )': '5 December 2018,18:16', 'Launch site': 'F9 B5B1050[268]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-16(Dragon C112.2♺ )', 'Orbit': '2,500\xa0kg (5,500\xa0lb)[382]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '66', 'Date and time ( )': '23 December 2018,13:51[386]', 'Launch site': 'F9 B5B1054[387]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'GPS III-01(Vespucci)', 'Orbit': '4,400\xa0kg (9,700\xa0lb)[388]', 'Customer': 'MEO', 'Launch outcome': 'USAF'}
# {'Flight No.': '67', 'Date and time ( )': '11 January 2019,15:31[396]', 'Launch site': 'F9 B5♺B1049.2[397]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Iridium NEXT-8(10 satellites)[152]', 'Orbit': '9,600\xa0kg (21,200\xa0lb)', 'Customer': 'PolarLEO', 'Launch outcome': 'Iridium Communications'}
# {'Flight No.': '68', 'Date and time ( )': '22 February 2019,01:45[398]', 'Launch site': 'F9 B5♺B1048.3[399]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Nusantara Satu(PSN-6)[400]BeresheetMoon lander[401]S5[402]', 'Orbit': '4,850\xa0kg (10,690\xa0lb)[403]', 'Customer': 'GTO', 'Launch outcome': 'PSNSpaceIL/IAIAir Force Research'}
# {'Flight No.': '69', 'Date and time ( )': '2 March 2019,07:49[412]', 'Launch site': 'F9 B5B1051.1[268][413]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Crew Dragon Demo-1[414](Dragon C201)', 'Orbit': '12,055\xa0kg (26,577\xa0lb)[415][h]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CCD)'}
# {'Flight No.': '70', 'Date and time ( )': '4 May 2019,06:48', 'Launch site': 'F9 B5B1056.1[420]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-17[141](Dragon C113.2 ♺)', 'Orbit': '2,495\xa0kg (5,501\xa0lb)[432]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '71', 'Date and time ( )': '24 May 2019,02:30', 'Launch site': 'F9 B5♺B1049.3[434]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlinkv0.9(60 satellites)', 'Orbit': '13,620\xa0kg (30,030\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '72', 'Date and time ( )': '12 June 2019,14:17', 'Launch site': 'F9 B5♺B1051.2[420]', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'RADARSAT Constellation(3 satellites)', 'Orbit': '4,200\xa0kg (9,300\xa0lb)[443]', 'Customer': 'SSO', 'Launch outcome': 'Canadian Space Agency(CSA)'}
# {'Flight No.': '73', 'Date and time ( )': '25 July 2019,22:01[464]', 'Launch site': 'F9 B5♺B1056.2[465]', 'Payload': 'CCAFSSLC-40', 'Payload mass': 'SpaceX CRS-18[141](Dragon C108.3 ♺)', 'Orbit': '2,268\xa0kg (5,000\xa0lb)[464]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '74', 'Date and time ( )': '6 August 2019,23:23[471]', 'Launch site': 'F9 B5♺B1047.3[472]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'AMOS-17[473]', 'Orbit': '6,500\xa0kg (14,300\xa0lb)[474]', 'Customer': 'GTO', 'Launch outcome': 'Spacecom'}
# {'Flight No.': '75', 'Date and time ( )': '11 November 2019,14:56[479]', 'Launch site': 'F9 B5♺B1048.4', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink1 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '76', 'Date and time ( )': '5 December 2019,17:29[481]', 'Launch site': 'F9 B5B1059.1[482]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-19[483](Dragon C106.3 ♺)', 'Orbit': '2,617\xa0kg (5,769\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '77', 'Date and time ( )': '17 December 2019,00:10[486]', 'Launch site': 'F9 B5♺B1056.3[482]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'JCSat-18/Kacific 1[487]', 'Orbit': '6,956\xa0kg (15,335\xa0lb)[486]', 'Customer': 'GTO', 'Launch outcome': 'Sky Perfect JSATKacific 1'}
# {'Flight No.': '78', 'Date and time ( )': '7 January 2020,02:19:21[492]', 'Launch site': 'F9 B5♺B1049.4', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink2 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '79', 'Date and time ( )': '19 January 2020,15:30[494]', 'Launch site': 'F9 B5♺B1046.4', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Crew Dragon in-flight abort test[495](Dragon C205.1)', 'Orbit': '12,050\xa0kg (26,570\xa0lb)', 'Customer': 'Sub-orbital[496]', 'Launch outcome': 'NASA(CTS)[497]'}
# {'Flight No.': '80', 'Date and time ( )': '29 January 2020,14:07[501]', 'Launch site': 'F9 B5♺B1051.3', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink3 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '81', 'Date and time ( )': '17 February 2020,15:05[503]', 'Launch site': 'F9 B5♺B1056.4', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink4 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '82', 'Date and time ( )': '7 March 2020,04:50[506]', 'Launch site': 'F9 B5♺B1059.2', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SpaceX CRS-20(Dragon C112.3 ♺)', 'Orbit': '1,977\xa0kg (4,359\xa0lb)[507]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '83', 'Date and time ( )': '18 March 2020,12:16[510]', 'Launch site': 'F9 B5♺B1048.5', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink5 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '84', 'Date and time ( )': '22 April 2020,19:30[514]', 'Launch site': 'F9 B5♺B1051.4', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink6 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '85', 'Date and time ( )': '30 May 2020,19:22[517]', 'Launch site': 'F9 B5B1058.1[518]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Crew Dragon Demo-2[414](Crew Dragon C206.1Endeavour)', 'Orbit': '12,530\xa0kg (27,620\xa0lb)[519]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CCDev)'}
# {'Flight No.': '86', 'Date and time ( )': '4 June 2020,01:25[521]', 'Launch site': 'F9 B5♺B1049.5', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink7 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '87', 'Date and time ( )': '13 June 2020,09:21[523]', 'Launch site': 'F9 B5♺B1059.3', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink8 v1.0 (58 satellites),[524][525]SkySats-16, -17, -18', 'Orbit': '15,410\xa0kg (33,970\xa0lb)[523]', 'Customer': 'LEO', 'Launch outcome': 'SpaceXPlanet Labs'}
# {'Flight No.': '88', 'Date and time ( )': '30 June 2020,20:10:46[529]', 'Launch site': 'F9 B5B1060.1', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'GPS III-03(Matthew Henson)', 'Orbit': '4,311\xa0kg (9,504\xa0lb)[530]', 'Customer': 'MEO', 'Launch outcome': 'U.S. Space Force[530]'}
# {'Flight No.': '89', 'Date and time ( )': '20 July 2020,21:30[543]', 'Launch site': 'F9 B5♺B1058.2[544]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'ANASIS-II', 'Orbit': '5,000–6,000\xa0kg (11,000–13,000\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Republic of Korea Army'}
# {'Flight No.': '90', 'Date and time ( )': '7 August 2020,05:12[549]', 'Launch site': 'F9 B5♺B1051.5', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink9 v1.0 (57 Satellites),[524]SXRS-1 (BlackSky Global 7 and 8)', 'Orbit': '14,932\xa0kg (32,919\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceXSpaceflight Industries(BlackSky)'}
# {'Flight No.': '91', 'Date and time ( )': '18 August 202014:31[553]', 'Launch site': 'F9 B5♺B1049.6[544]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink10 v1.0 (58 satellites)SkySat-19, -20, -21', 'Orbit': '~15,440\xa0kg (34,040\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceXPlanet Labs'}
# {'Flight No.': '92', 'Date and time ( )': '30 August 202023:18[555]', 'Launch site': 'F9 B5♺B1059.4', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'SAOCOM 1B[556]GNOMES 1[556]Tyvak-0172[557]', 'Orbit': '3,130\xa0kg (6,900\xa0lb)[558]', 'Customer': 'SSO', 'Launch outcome': 'CONAEPlanetIQTyvak'}
# {'Flight No.': '93', 'Date and time ( )': '3 September 202012:46:14[562]', 'Launch site': 'F9 B5♺B1060.2[563]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink11 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '94', 'Date and time ( )': '6 October 202011:29:34[564]', 'Launch site': 'F9 B5♺B1058.3[565]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink12 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '95', 'Date and time ( )': '18 October 202012:25:57[567]', 'Launch site': 'F9 B5♺B1051.6[568]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink13 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)[5]', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '96', 'Date and time ( )': '24 October 202015:31:34[570]', 'Launch site': 'F9 B5♺B1060.3', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink14 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '97', 'Date and time ( )': '5 November 202023:24:23[572]', 'Launch site': 'F9 B5B1062.1', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'GPS III-04(Sacagawea)[541][573]', 'Orbit': '4,311\xa0kg (9,504\xa0lb)', 'Customer': 'MEO', 'Launch outcome': 'USSF'}
# {'Flight No.': '98', 'Date and time ( )': '16 November 202000:27[581]', 'Launch site': 'F9 B5B1061.1[582]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Crew-1(Crew Dragon C207.1Resilience)', 'Orbit': '~12,500\xa0kg (27,600\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CCP)[497]'}
# {'Flight No.': '99', 'Date and time ( )': '21 November 202017:17:08[587]', 'Launch site': 'F9 B5B1063.1', 'Payload': 'VAFB,SLC-4E', 'Payload mass': 'Sentinel-6 Michael Freilich (Jason-CS A)', 'Orbit': '1,192\xa0kg (2,628\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'NASA/NOAA/ESA/EUMETSAT'}
# {'Flight No.': '100', 'Date and time ( )': '25 November 202002:13[589]', 'Launch site': 'F9 B5 ♺B1049.7[590]', 'Payload': 'CCAFS,SLC-40', 'Payload mass': 'Starlink15 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '101', 'Date and time ( )': '6 December 202016:17:08[591]', 'Launch site': 'F9 B5 ♺B1058.4[592]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SpaceX CRS-21(Dragon C208.1)', 'Orbit': '2,972\xa0kg (6,552\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '102', 'Date and time ( )': '13 December 202017:30:00[596]', 'Launch site': 'F9 B5 ♺B1051.7', 'Payload': 'CCSFS,SLC-40[597]', 'Payload mass': 'SXM-7', 'Orbit': '7,000\xa0kg (15,000\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Sirius XM'}
# {'Flight No.': '103', 'Date and time ( )': '19 December 202014:00:00[602]', 'Launch site': 'F9 B5 ♺B1059.5', 'Payload': 'KSC,LC-39A', 'Payload mass': 'NROL-108', 'Orbit': 'Classified', 'Customer': 'LEO', 'Launch outcome': 'NRO'}
# {'Flight No.': '104', 'Date and time ( )': '8 January 202102:15[604]', 'Launch site': 'F9 B5♺B1060.4', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Türksat 5A[605]', 'Orbit': '3,500\xa0kg (7,700\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Türksat'}
# {'Flight No.': '105', 'Date and time ( )': '20 January 202113:02[608]', 'Launch site': 'F9 B5♺B1051.8[609]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink16 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '106', 'Date and time ( )': '24 January 202115:00[612]', 'Launch site': 'F9 B5♺B1058.5[613]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Transporter-1(143 smallsat rideshare)', 'Orbit': '~5,000\xa0kg (11,000\xa0lb)', 'Customer': 'SSO', 'Launch outcome': 'Various'}
# {'Flight No.': '107', 'Date and time ( )': '4 February 202106:19[623]', 'Launch site': 'F9 B5 ♺B1060.5[624]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink18 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '108', 'Date and time ( )': '16 February 202103:59:37[626]', 'Launch site': 'F9 B5 ♺B1059.6', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink19 v1.0 (60 satellites)[627]', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '109', 'Date and time ( )': '4 March 202108:24[633]', 'Launch site': 'F9 B5 ♺B1049.8[634]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink17 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '110', 'Date and time ( )': '11 March 202108:13:29[637]', 'Launch site': 'F9 B5 ♺B1058.6[638]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink20 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '111', 'Date and time ( )': '14 March 202110:01[640]', 'Launch site': 'F9 B5 ♺B1051.9', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink21 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '112', 'Date and time ( )': '24 March 202108:28[642]', 'Launch site': 'F9 B5♺B1060.6[643]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink22 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '113', 'Date and time ( )': '7 April 202116:34', 'Launch site': 'F9 B5 ♺B1058.7', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink23 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '114', 'Date and time ( )': '23 April 20219:49[646]', 'Launch site': 'F9 B5♺B1061.2[647]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Crew-2(Crew Dragon C206.2Endeavour♺)', 'Orbit': '~13,000\xa0kg (29,000\xa0lb)[648]', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CTS)[497]'}
# {'Flight No.': '115', 'Date and time ( )': '29 April 202103:44[651]', 'Launch site': 'F9 B5♺B1060.7[652]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink24 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '116', 'Date and time ( )': '4 May 202119:01[654]', 'Launch site': 'F9 B5♺B1049.9[655]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'Starlink25 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '117', 'Date and time ( )': '9 May 202106:42[656]', 'Launch site': 'F9 B5♺B1051.10[657]', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'Starlink27 v1.0 (60 satellites)', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '118', 'Date and time ( )': '15 May 202122:56[659]', 'Launch site': 'F9 B5♺B1058.8[660]', 'Payload': 'KSC,LC-39A[661]', 'Payload mass': 'Starlink26 v1.0 (52 Satellites)Capella-6 &Tyvak-0130[662]', 'Orbit': '~14,000\xa0kg (31,000\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceXCapella SpaceandTyvak'}
# {'Flight No.': '119', 'Date and time ( )': '26 May 202118:59[664]', 'Launch site': 'F9 B5♺B1063.2[665]', 'Payload': 'CCSFS,SLC-40[665]', 'Payload mass': 'Starlink28 v1.0 (60 Satellites)[665]', 'Orbit': '15,600\xa0kg (34,400\xa0lb)', 'Customer': 'LEO', 'Launch outcome': 'SpaceX'}
# {'Flight No.': '120', 'Date and time ( )': '3 June 202117:29[667]', 'Launch site': 'F9 B5B1067.1[668]', 'Payload': 'KSC,LC-39A', 'Payload mass': 'SpaceX CRS-22(Dragon C209.1)', 'Orbit': '3,328\xa0kg (7,337\xa0lb)', 'Customer': 'LEO(ISS)', 'Launch outcome': 'NASA(CRS)'}
# {'Flight No.': '121', 'Date and time ( )': '6 June 202104:26[673]', 'Launch site': 'F9 B5♺B1061.3', 'Payload': 'CCSFS,SLC-40', 'Payload mass': 'SXM-8[674]', 'Orbit': '7,000\xa0kg (15,000\xa0lb)', 'Customer': 'GTO', 'Launch outcome': 'Sirius XM'}

# %%
extracted_row = 0
#Extract each table 
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            #print(flight_number)
            datatimelist=date_time(row[0])
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            #print(date)
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            #print(time)
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            print(bv)
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            #print(launch_site)
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            #print(payload)
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            #print(payload)
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            #print(orbit)
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            customer = row[6].a.string
            #print(customer)
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            #print(launch_outcome)
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            #print(booster_landing)

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |
# -->

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
